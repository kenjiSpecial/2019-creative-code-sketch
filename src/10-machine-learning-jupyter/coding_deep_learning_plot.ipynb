# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df_data = pd.read_csv("cracow_apartments.csv", sep=",")

# %%
df_data.head()
# Out:
#    distance_to_city_center  rooms   size    price
# 0                      2.4    1.0  19.35  191.565
# 1                      2.4    2.0  13.08  221.568
# 2                      5.0    1.0  24.66  185.936
# 3                      1.9    1.0  24.82  275.502
# 4                      1.9    1.0  25.39  241.205

# %%
def init(n):
    return {"w": np.zeros(n), "b": 0.0}

# %%
def predict(x, parameters):
    # Prediction initial value
    prediction = 0
#     print(x)
#     print(parameters)
    
    # Adding multiplication of each feature with it's weight
    for weight, feature in zip(parameters["w"], x):
        prediction += weight * feature
        
    # Adding bias
    prediction += parameters["b"]
        
    return prediction

# %%
features = ["size"]
target = ["price"]
X, y = df_data[features].values, df_data[target].values
n = len(features)
model_parameters = init(n)
predictions =[predict(x, model_parameters) for x in X]

# %%
x_array = np.array(X)
x_array.flatten()
# Out:
# array([ 19.35,  13.08,  24.66,  24.82,  25.39,  25.54,  25.62,  26.04,
#         26.26,  26.26,  26.6 ,  26.87,  27.85,  27.86,  27.93,  28.32,
#         29.  ,  29.91,  30.83,  31.68,  32.02,  32.22,  34.32,  34.32,
#         34.78,  35.01,  37.11,  37.41,  38.7 ,  29.  ,  45.15,  48.17,
#         48.52,  49.42,  49.44,  50.91,  51.9 ,  52.4 ,  52.7 ,  53.61,
#         53.83,  53.86,  54.18,  54.9 ,  54.92,  54.97,  55.1 ,  67.35,
#         67.73,  68.6 ,  70.1 ,  70.16,  70.81,  71.81,  72.02,  74.36,
#         75.59,  75.92,  83.  ,  85.09,  86.86,  87.91,  96.21,  99.  ,
#        100.88, 106.96,  30.83,  36.95,  39.59,  40.69,  41.25,  41.31,
#         41.94,  34.18,  34.3 ,  34.4 ])

# %%
y.flatten()
# Out:
# array([191.565, 221.568, 185.936, 275.502, 241.205, 193.052, 231.861,
#        151.757, 172.003, 175.952, 234.08 , 185.967, 185.025, 261.884,
#        235.8  , 357.511, 287.1  , 297.605, 292.882, 234.432, 232.113,
#        209.43 , 272.844, 223.08 , 290.739, 224.064, 241.215, 299.28 ,
#        255.42 , 287.   , 234.735, 349.233, 272.227, 325.777, 360.418,
#        459.993, 321.98 , 393.   , 375.852, 427.023, 339.129, 350.9  ,
#        409.836, 334.89 , 389.932, 417.   , 413.25 , 451.245, 504.589,
#        418.46 , 455.65 , 614.809, 485.261, 495.489, 555.   , 714.183,
#        521.571, 529.753, 680.6  , 680.   , 464.18 , 483.505, 692.712,
#        782.1  , 700.   , 808.144, 292.885, 229.09 , 285.048, 287.6  ,
#        284.625, 325.   , 373.088, 177.702, 264.11 , 242.52 ])

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
# x_axis = np.mgrid[5:7:0.1]
# y_axis = np.mgrid[35:50:0.2]
x_axis = np.linspace(0, 10, num=100)
y_axis = np.linspace(0, 40, num=100)

# %%
print(model_parameters['w'][0])

print(model_parameters['b'])
# Out:
# 0.0
# 0.0

# %%
def mse(predictions, targets):
    # Retrieving number of samples in dataset
    samples_num = len(predictions)
    
    # Summing square differences between predicted and expected values
    accumulated_error = 0.0
    for prediction, target in zip(predictions, targets):
        accumulated_error += (prediction - target)**2
        
    # Calculating mean and dividing by 2
    mae_error = (1.0 / (2*samples_num)) * accumulated_error
    
    return mae_error

# %%
item_array = []
for y_item in np.nditer(y_axis):
    x_item_array = []
    for x_item in np.nditer(x_axis):
        loop_parameters = {'b': y_item, 'w': np.array([x_item])}
        predictions = [predict(x, loop_parameters) for x in X]
        mse_val = mse(predictions, y)
#         print(mse_val[0])
        x_item_array.append(mse_val[0])
    
    item_array.append(x_item_array)

# %%
def train2(X, y, model_parameters, learning_rate=0.00001, iterations=12000):
    # Make prediction for every data sample
    predictions = [predict(x, model_parameters) for x in X]

    # Calculate initial cost for model - MSE
    initial_error = mse(predictions, y)
    
    trains_w.append(model_parameters['w'][0])
    trains_b.append(model_parameters['b'])
    trains_mse.append(initial_error[0])
    
    print("Initial state:")
    print(" - error: {}".format(initial_error))
    print(" - parameters: {}".format(model_parameters))
    
    for i in range(iterations):
        # Sum up partial gradients for every data sample, for every parameter in model
        accumulated_grad_w0 = 0
        accumulated_grad_b = 0   
        for x, y_target in zip(X, y):
            accumulated_grad_w0 += (predict(x, model_parameters) - y_target)*x[0]
            accumulated_grad_b += (predict(x, model_parameters) - y_target)
            
        # Calculate mean of gradient
        w_grad = (1.0/len(X)) * accumulated_grad_w0
        b_grad = (1.0/len(X)) * accumulated_grad_b
        
        # Update parameters by small part of averaged gradient
        model_parameters["w"][0] = model_parameters["w"][0] - learning_rate * w_grad
        model_parameters["b"] = model_parameters["b"] - learning_rate * b_grad
        
        if i % 4000 == 0:
            print("\nIteration {}:".format(i))
            print(" - error: {}".format(mse([predict(x, model_parameters) for x in X], y)))
            print(" - parameters: {}".format(model_parameters))
        
        if i % 100 == 0 or (i > 1 and i < 100):
            trains_w.append(model_parameters['w'][0])
            trains_b.append(model_parameters['b'][0])
            trains_mse.append(mse([predict(x, model_parameters) for x in X], y)[0])
            
        
        if i % 20 == 0:
            data_w.append(model_parameters['w'][0])
            data_b.append(model_parameters['b'][0])
            
            
    print("\nFinal state:")
    print(" - error: {}".format(mse([predict(x, model_parameters) for x in X], y)))
    print(" - parameters: {}".format(model_parameters))

# %%
trains_w = []
trains_b = []
trains_mse = []

data_w = []
data_b = []

model_parameters = init(n)
train2(X, y, model_parameters)
# Out:
# Initial state:
#  - error: [75870.4884482]
#  - parameters: {'w': array([0.]), 'b': 0.0}
#
# Iteration 0:
#  - error: [71785.89050732]
#  - parameters: {'w': array([0.20350039]), 'b': array([0.00356868])}
#
# Iteration 4000:
#  - error: [1795.02828104]
#  - parameters: {'w': array([7.27337638]), 'b': array([0.3805391])}
#
# Iteration 8000:
#  - error: [1793.42251814]
#  - parameters: {'w': array([7.26901236]), 'b': array([0.63393854])}
#
# Final state:
#  - error: [1791.83896096]
#  - parameters: {'w': array([7.26467917]), 'b': array([0.88554832])}

# %%
z_values = np.array(item_array)

# %%
fig = go.Figure(data=[go.Surface(z=z_values, x=x_axis, y=y_axis),go.Scatter3d(x=trains_w, y=trains_b, z=trains_mse, mode='markers')])

# %%
fig.show()
# Out:
# <div>
#
#
#             <div id="b18e833f-70b3-42c9-8fb6-45108e7da426" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("
 25.05050505050505, 25.454545454545453, 25.858585858585858, 26.262626262626263, 26.666666666666668, 27.07070707070707, 27.474747474747474, 27.87878787878788, 28.282828282828284, 28.686868686868685, 29.09090909090909, 29.494949494949495, 29.8989898989899, 30.3030303030303, 30.707070707070706, 31.11111111111111, 31.515151515151516, 31.919191919191917, 32.323232323232325, 32.72727272727273, 33.13131313131313, 33.535353535353536, 33.93939393939394, 34.343434343434346, 34.74747474747475, 35.15151515151515, 35.55555555555556, 35.95959595959596, 36.36363636363636, 36.76767676767677, 37.17171717171717, 37.57575757575758, 37.97979797979798, 38.38383838383838, 38.78787878787879, 39.19191919191919, 39.5959595959596, 40.0], "z": [[75870.48844819736, 73829.18959193071, 71816.4120820089, 69832.155918432, 67876.42110120002, 65949.20763031 ...

# %%
xx = np.linspace(0, 120, 2)
train_frame_data = []

# go.Frame(data=[go.Scatter(x=[1, 2], y=[1, 2])]),
#             go.Frame(data=[go.Scatter(x=[1, 4], y=[1, 4])]),
#             go.Frame(data=[go.Scatter(x=[3, 4], y=[3, 4])]

frame_cnt = 0
# [go.Frame(data=[go.Scatter(x=[1, 2], y=[1, 2])]),
#             go.Frame(data=[go.Scatter(x=[1, 4], y=[1, 4])]),
#             go.Frame(data=[go.Scatter(x=[3, 4], y=[3, 4])],
#                      layout=go.Layout(title_text="End Title"))]
for w, b in np.nditer([data_w, data_b]):
    one_frame = {"data": {}, "name": str(frame_cnt)}
    y_value_array = []
    x_value_array = []
    for x_value in np.nditer(xx):
        y_value = x_value * w + b
        
        y_value_array.append(y_value)
        x_value_array.append(x_value)
        
#     print(x_value_array)
#     print(y_value_array)
    train_frame_data.append(go.Frame(data=[go.Scatter(x=np.array(x_value_array), y=np.array(y_value_array), mode="lines")]))
    
    
print(train_frame_data)
# Out:
# [Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([3.56867974e-03, 2.44236159e+01])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([5.75891221e-02, 3.91963997e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([8.87785201e-02, 6.00397794e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([1.07020275e-01, 7.18601278e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([1.17919323e-01, 7.85634603e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([1.24654259e-01, 8.23649019e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([1.29027683e-01, 8.45206635e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([1.32061859e-01, 8.57431499e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([1.34336521e-01, 8.64363703e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([1.36180440e-01, 8.68294407e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([1.37780062e-01, 8.70522943e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([1.39241123e-01, 8.71786168e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([1.40623586e-01, 8.72501960e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([1.41961457e-01, 8.72907299e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([1.43274021e-01, 8.73136579e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([1.44572213e-01, 8.73266014e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([1.45862237e-01, 8.73338827e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([1.47147610e-01, 8.73379528e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([1.48430325e-01, 8.73402020e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([1.49711515e-01, 8.73414185e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([1.50991821e-01, 8.73420492e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([1.52271607e-01, 8.73423479e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([1.53551078e-01, 8.73424582e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([1.54830353e-01, 8.73424617e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([1.56109497e-01, 8.73424047e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([1.57388547e-01, 8.73423132e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([1.58667526e-01, 8.73422024e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([1.59946446e-01, 8.73420804e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([1.61225313e-01, 8.73419522e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([1.62504131e-01, 8.73418205e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([1.63782902e-01, 8.73416867e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([1.65061628e-01, 8.73415518e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([1.66340309e-01, 8.73414163e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([1.67618947e-01, 8.73412804e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([1.68897540e-01, 8.73411443e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([1.70176089e-01, 8.73410081e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([1.71454594e-01, 8.73408718e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([1
+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([8.10289905e-01, 8.72727321e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([8.11546524e-01, 8.72725981e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([8.12803100e-01, 8.72724641e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([8.14059632e-01, 8.72723301e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([8.15316122e-01, 8.72721960e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([8.16572569e-01, 8.72720620e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([8.17828973e-01, 8.72719280e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([8.19085334e-01, 8.72717940e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([8.20341651e-01, 8.72716600e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([8.21597926e-01, 8.72715260e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([8.22854158e-01, 8.72713920e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([8.24110347e-01, 8.72712580e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([8.25366493e-01, 8.72711240e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([8.26622597e-01, 8.72709901e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([8.27878657e-01, 8.72708561e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([8.29134674e-01, 8.72707221e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([8.30390648e-01, 8.72705881e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([8.31646580e-01, 8.72704542e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([8.32902468e-01, 8.72703202e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([8.34158313e-01, 8.72701863e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([8.35414116e-01, 8.72700523e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([8.36669876e-01, 8.72699184e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([8.37925592e-01, 8.72697845e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([8.39181266e-01, 8.72696505e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([8.40436897e-01, 8.72695166e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([8.41692484e-01, 8.72693827e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([8.42948029e-01, 8.72692487e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([8.44203531e-01, 8.72691148e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([8.45458990e-01, 8.72689809e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([8.46714407e-01, 8.72688470e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([8.47969780e-01, 8.72687131e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([8.49225110e-01, 8.72685792e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([8.50480397e-01, 8.72684453e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([8.51735642e-01, 8.72683114e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([8.52990843e-01, 8.72681776e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([8.54246002e-01, 8.72680437e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([8.55501118e-01, 8.72679098e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([8.56756190e-01, 8.72677759e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([8.58011220e-01, 8.72676421e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([8.59266207e-01, 8.72675082e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([8.60521151e-01, 8.72673744e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([8.61776052e-01, 8.72672405e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([8.63030910e-01, 8.72671067e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([8.64285726e-01, 8.72669728e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([8.65540498e-01, 8.72668390e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([8.66795228e-01, 8.72667051e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([8.68049914e-01, 8.72665713e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([8.69304558e-01, 8.72664375e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([8.70559159e-01, 8.72663037e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([8.71813717e-01, 8.72661699e+02])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([  0.87306823, 872.66036051])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([  0.8743227 , 872.65902246])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([  0.87557713, 872.65768446])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([  0.87683152, 872.6563465 ])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([  0.87808586, 872.65500858])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([  0.87934016, 872.65367072])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([  0.88059442, 872.65233289])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([  0.88184864, 872.65099512])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([  0.88310281, 872.64965739])}]
# }), Frame({
#     'data': [{'mode': 'lines', 'type': 'scatter', 'x': array([  0., 120.]), 'y': array([  0.88435694, 872.6483197 ])}]
# })]

# %%
len(train_frame_data)
# Out:
# 600

# %%
fig2 = go.Figure(
    data=[go.Scatter(x=x_array.flatten(), y=y.flatten(), mode='markers'),
          go.Scatter(x=x_array.flatten(), y=y.flatten(), mode='markers')],
    layout=go.Layout(
        updatemenus=[dict(type="buttons",
                          buttons=[dict(label="Play",
                                        method="animate",
                                        args=[None])])]),
    frames=train_frame_data
)

fig2.show()
# Out:
# <div>
#
#
#             <div id="3a73c61b-a31c-462f-b676-18d9b0647b12" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3a73c61b-a31c-462f-b676-18d9b0647b12")) {
#                     Plotly.newPlot(
#                         '3a73c61b-a31c-462f-b676-18d9b0647b12',
